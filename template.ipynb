# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
from generate import generate_maze

# %%
from dataclasses import dataclass, field

@dataclass
class MazeCell:
    x: int
    y: int
    component: int
    is_open: bool = field(default=False)
    walls: list = field(default_factory=list)

# %%
N = 30
LINE_WIDTH = 50

# %%
"""
В этой ячейке должен быть код генератора лабиринта
"""

def find(x):
    pass

def union(x, y):
    pass

def generate_maze() -> list[list[MazeCell]]:
    pass

# %%
maze = generate_maze(N)

# %%
def draw_maze(maze):
    """
    TODO:
    - Написать функцию отрисовки матрицы ячеек лабиринта
    
    Функция отрисовки линии 
    plt.plot([start_x, end_x], [start_y, end_y], 'k-', lw=2)
    """
    pass

# %%
fig = plt.figure(figsize=(10, 10))
                    
draw_maze(maze)

plt.show()
